# %% [markdown]
# # Criação de página web para cadastro dos agentes de Vigilância Sanitária

# %% [markdown]
# ## Criação dos bancos de dados e back-end

# %%
#Instalação de bibliotecas necessárias
#!pip install python-multipart
#!pip install nest_asyncio
#!pip install pydantic[email]
# Out:
# Requirement already satisfied: pydantic[email] in c:\users\lucas\anaconda3\lib\site-packages (2.5.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\lucas\anaconda3\lib\site-packages (from pydantic[email]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\lucas\anaconda3\lib\site-packages (from pydantic[email]) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\lucas\anaconda3\lib\site-packages (from pydantic[email]) (4.13.2)
# Collecting email-validator>=2.0.0 (from pydantic[email])
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->pydantic[email])
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: idna>=2.0.0 in c:\users\lucas\anaconda3\lib\site-packages (from email-validator>=2.0.0->pydantic[email]) (3.7)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ---------------------------------------- 0.0/313.6 kB ? eta -:--:--
#    --------------------------- ------------ 215.0/313.6 kB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 313.6/313.6 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: dnspython, email-validator
# Successfully installed dnspython-2.7.0 email-validator-2.2.0

# %%
# Importações
from fastapi import FastAPI, Depends, HTTPException, status, Request, Query, APIRouter
from fastapi.security import OAuth2PasswordBearer, OAuth2PasswordRequestForm
from jose import JWTError, jwt
from passlib.context import CryptContext
from sqlalchemy import create_engine, Column, String, DateTime, ForeignKey, and_, Integer, select, func, engine_from_config, pool
from sqlalchemy.orm import sessionmaker, declarative_base, relationship
from sqlalchemy.ext.asyncio import AsyncSession, create_async_engine, async_sessionmaker
from sqlalchemy.future import select
from datetime import datetime, timedelta, date
from typing import Optional, Annotated
from pydantic import BaseModel, field_validator, EmailStr, constr
from slowapi import Limiter, _rate_limit_exceeded_handler
from slowapi.util import get_remote_address
from slowapi.errors import RateLimitExceeded
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.future import select
from rotas_opcoes import router_opcoes
import threading
from threading import Thread
import ssl
import asyncio
import nest_asyncio
import uuid
import os
import uvicorn
import pandas as pd

# %%
# Configurações
DATABASE_URL = os.getenv("DATABASE_URL", "postgresql+asyncpg://neondb_owner:npg_RaZNeP4EuFT8@ep-ancient-rice-a8mud72e-pooler.eastus2.azure.neon.tech/neondb?")
SECRET_KEY = os.getenv("SECRET_KEY", "chave-padrao-insegura")
ALGORITHM = os.getenv("ALGORITHM", "HS256")
ACCESS_TOKEN_EXPIRE_MINUTES = int(os.getenv("TOKEN_EXPIRE", 60))

# %%
# Inicar sessão para criação de banco de dados assíncrono no Railway
ssl_context = ssl.create_default_context()
engine = create_async_engine(DATABASE_URL, connect_args={"ssl": ssl_context}, echo=True)
async_session = sessionmaker(bind=engine, class_=AsyncSession, expire_on_commit=False)
async def get_async_session() -> AsyncSession:
    async with async_session() as session:
        yield session
Base = declarative_base()
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_13644\2336664541.py:8: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
# Hash de senha
pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto") # criptografar/verificar senhas

# Auth
oauth2_scheme = OAuth2PasswordBearer(tokenUrl="/auth/login") # usar tokens JWT em rotas protegidas

# %% [markdown]
# ### Descrição dos bancos de dados

# %%
# Banco de dados de cadastro dos usuários
class Usuario(Base):
    __tablename__ = "cadastro_usuarios"
    id = Column(String, primary_key=True, default=lambda: str(uuid.uuid4()))
    nome = Column(String)
    email = Column(String, unique=True)
    senha = Column(String)
    criado_em = Column(DateTime, default=datetime.utcnow)
    agentes = relationship("Agente", back_populates="usuario")

# %%
# Banco de dados de cadastro dos agentes 
class Agente(Base):
    __tablename__ = "agentes"
    id = Column(String, primary_key=True, default=lambda: str(uuid.uuid4()))
    usuario_id = Column(String, ForeignKey("cadastro_usuarios.id"))
    usuario = relationship("Usuario", back_populates="agentes")

    nu_cpf = Column(String, unique=True)
    nu_cns_cnes = Column(String)
    co_especialidade = Column(String)
    co_nivel_escolaridade = Column(String)
    co_capacitacao = Column(String)
    co_cbo_cnes = Column(String)
    ds_vinculo_empregaticio = Column(String)
    ds_cargo = Column(String)
    co_faixa_etaria = Column(String)
    co_genero = Column(String)
    co_unidade_vigilancia_sanitaria = Column(String)
    co_cep = Column(String)
    municipio = Column(String)
    regiao_saude = Column(String)
    crs = Column(String)
    macrorregiao = Column(String)
    criado_em = Column(DateTime, default=datetime.utcnow)
    atualizado_em = Column(DateTime, default=datetime.utcnow, onupdate=datetime.utcnow)

# %%
# Banco de dados de tentativas de login
class TentativaLogin(Base):
    __tablename__ = "tentativas_login"
    id = Column(String, primary_key=True, default=lambda: str(uuid.uuid4()))
    email = Column(String, index=True)
    tentativas = Column(Integer, default=0)
    ultima_tentativa = Column(DateTime, default=datetime.utcnow)

# %% [markdown]
# ### Validação de dados inseridos no banco "cadastro_usuarios"

# %%
# Validação dos dados inseridos no banco "cadastro_usuarios"
class UsuarioCreate(BaseModel):
    nome: str
    email: EmailStr
    senha: str

# %%
# Inserção de informações que serão utilizados no retorno (GET) como resposta completa dos cadastros
class UsuarioOut(BaseModel):
    id: str
    nome: str
    email: EmailStr

    class Config:
        from_attributes = True

# %% [markdown]
# ### Validação de dados inseridos no banco "agentes"

# %%
# Validação dos dados inseridos no banco "agentes"
class AgenteCreate(BaseModel):
    nu_cpf: str
    data_nascimento: date
    nu_cns_cnes: Optional[str] = None
    co_especialidade: Optional[str] = None
    co_nivel_escolaridade: Optional[str] = None
    co_capacitacao: Optional[str] = None
    co_cbo_cnes: Optional[str] = None
    ds_vinculo_empregaticio: Optional[str] = None
    ds_cargo: Optional[str] = None
    co_faixa_etaria: Optional[str] = None
    co_genero: Optional[str] = None
    co_unidade_vigilancia_sanitaria: Optional[str] = None
    co_cep: Optional[str] = None
    municipio: Optional[str] = None
    regiao_saude: Optional[str] = None
    crs: Optional[str] = None
    macrorregiao: Optional[str] = None

# %%
# Função para calcular a idade a partir da data de nascimento utilizando o Pydantic Validator (@model_validator)
@field_validator('co_faixa_etaria', mode='before')
@classmethod
def calcular_idade_em_anos(cls, v, values):
        data_nascimento = values.get('data_nascimento')
        if data_nascimento:
            hoje = date.today()
            idade = hoje.year - data_nascimento.year
            if (hoje.month, hoje.day) < (data_nascimento.month, data_nascimento.day):
                idade -= 1  # ainda não fez aniversário este ano
            return f"{idade} anos"
        return v

# %%
# Inserção de informações que serão utilizados no retorno (GET) como resposta completa dos agentes
class AgenteOut(AgenteCreate):
    id: str
    criado_em: datetime
    atualizado_em: datetime

    class Config:
        from_attributes = True

# %%
# Validação para recebimento de filtros para busca de agentes
class FiltroAgente(BaseModel):
    municipio: Optional[str] = None
    co_especialidade: Optional[str] = None
    co_genero: Optional[str] = None
    nu_cpf: Optional[str] = None
    order_by: Optional[str] = "criado_em"
    order_dir: Optional[str] = "desc"

# %% [markdown]
# ### Inicializar os bancos de dados assíncronos no Neon

# %%
# Inicializa o banco
async def criar_tabelas():
    async with engine.begin() as conn:
        await conn.run_sync(Base.metadata.create_all)

await criar_tabelas()
# Out:
# 2025-06-14 16:05:31,074 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-06-14 16:05:31,074 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-14 16:05:31,666 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-06-14 16:05:31,666 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-14 16:05:32,299 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-06-14 16:05:32,301 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-06-14 16:05:32,750 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-14 16:05:32,761 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = $1::VARCHAR AND pg_catalog.pg_class.relkind = ANY (ARRAY[$2::VARCHAR, $3::VARCHAR, $4::VARCHAR, $5::VARCHAR, $6::VARCHAR]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != $7::VARCHAR
# 2025-06-14 16:05:32,761 INFO sqlalchemy.engine.Engine [generated in 0.00068s] ('cadastro_usuarios', 'r', 'p', 'f', 'v', 'm', 'pg_catalog')
# 2025-06-14 16:05:33,198 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = $1::VARCHAR AND pg_catalog.pg_class.relkind = ANY (ARRAY[$2::VARCHAR, $3::VARCHAR, $4::VARCHAR, $5::VARCHAR, $6::VARCHAR]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != $7::VARCHAR
# 2025-06-14 16:05:33,198 INFO sqlalchemy.engine.Engine [cached since 0.4481s ago] ('agentes', 'r', 'p', 'f', 'v', 'm', 'pg_catalog')
# 2025-06-14 16:05:33,352 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = $1::VARCHAR AND pg_catalog.pg_class.relkind = ANY (ARRAY[$2::VARCHAR, $3::VARCHAR, $4::VARCHAR, $5::VARCHAR, $6::VARCHAR]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != $7::VARCHAR
# 2025-06-14 16:05:33,352 INFO sqlalchemy.engine.Engine [cached since 0.6027s ago] ('tentativas_login', 'r', 'p', 'f', 'v', 'm', 'pg_catalog')
# 2025-06-14 16:05:33,497 INFO sqlalchemy.engine.Engine
# CREATE TABLE cadastro_usuarios (
# 	id VARCHAR NOT NULL,
# 	nome VARCHAR,
# 	email VARCHAR,
# 	senha VARCHAR,
# 	criado_em TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (id),
# 	UNIQUE (email)
# )
#
#
# 2025-06-14 16:05:33,497 INFO sqlalchemy.engine.Engine [no key 0.00156s] ()
# 2025-06-14 16:05:33,831 INFO sqlalchemy.engine.Engine
# CREATE TABLE tentativas_login (
# 	id VARCHAR NOT NULL,
# 	email VARCHAR,
# 	tentativas INTEGER,
# 	ultima_tentativa TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (id)
# )
#
#
# 2025-06-14 16:05:33,831 INFO sqlalchemy.engine.Engine [no key 0.00159s] ()
# 2025-06-14 16:05:34,118 INFO sqlalchemy.engine.Engine CREATE INDEX ix_tentativas_login_email ON tentativas_login (email)
# 2025-06-14 16:05:34,118 INFO sqlalchemy.engine.Engine [no key 0.00179s] ()
# 2025-06-14 16:05:34,399 INFO sqlalchemy.engine.Engine
# CREATE TABLE agentes (
# 	id VARCHAR NOT NULL,
# 	usuario_id VARCHAR,
# 	nu_cpf VARCHAR,
# 	nu_cns_cnes VARCHAR,
# 	co_especialidade VARCHAR,
# 	co_nivel_escolaridade VARCHAR,
# 	co_capacitacao VARCHAR,
# 	co_cbo_cnes VARCHAR,
# 	ds_vinculo_empregaticio VARCHAR,
# 	ds_cargo VARCHAR,
# 	co_faixa_etaria VARCHAR,
# 	co_genero VARCHAR,
# 	co_unidade_vigilancia_sanitaria VARCHAR,
# 	co_cep VARCHAR,
# 	municipio VARCHAR,
# 	regiao_saude VARCHAR,
# 	crs VARCHAR,
# 	macrorregiao VARCHAR,
# 	criado_em TIMESTAMP WITHOUT TIME ZONE,
# 	atualizado_em TIMESTAMP WITHOUT TIME ZONE,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(usuario_id) REFERENCES cadastro_usuarios (id),
# 	UNIQUE (nu_cpf)
# )
#
#
# 2025-06-14 16:05:34,415 INFO sqlalchemy.engine.Engine [no key 0.00211s] ()
# 2025-06-14 16:05:34,715 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Criação da API e limitação de requisições

# %%
# App FastAPI
app = FastAPI()

router = APIRouter()

# Configuração para cadastro de usuários
@router.post("/auth/cadastrar", response_model=UsuarioOut)
async def cadastrar_usuario(usuario: UsuarioCreate, db: AsyncSession = Depends(get_async_session)):

    # Verifica se email já existe
    resultado = await db.execute(select(Usuario).where(Usuario.email == usuario.email))
    usuario_existente = resultado.scalar_one_or_none()

    if usuario_existente:
        raise HTTPException(status_code=400, detail="Email já cadastrado")

    # Cria a instância do usuário
    novo_usuario = Usuario(
        id=str(uuid.uuid4()),
        nome=usuario.nome,
        email=usuario.email,
        senha=hash_password(usuario.senha),
        criado_em=datetime.utcnow()
    )

    db.add(novo_usuario)
    await db.commit()
    await db.refresh(novo_usuario)

    return {"id": novo_usuario.id, "nome": novo_usuario.nome, "email": novo_usuario.email}

app.include_router(router, tags=["Autenticação"])

# Configuração da rota para obter dados de preenchimento automático de opções do "rotas_opcoes.py"
app.include_router(router_opcoes, prefix="/opcoes", tags=["Opções"])

# Configuração da rota para obter dados do município 
@router.get("/municipio_info/{municipio}")
async def get_municipio_info(municipio: str, db: AsyncSession = Depends(get_async_session)):
    info = await db.execute(
        select(MunicipioInfo).where(MunicipioInfo.municipio == municipio)
    )
    info = info.scalar_one_or_none()
    if not info:
        raise HTTPException(status_code=404, detail="Município não encontrado")
    
    return {
        "municipio": info.municipio,
        "regiao_saude": info.regiao_saude,
        "crs": info.crs,
        "macrorregiao": info.macrorregiao
    }

# %%
# Configurar o CORS (Cross-Origin Resource Sharing)

from fastapi.middleware.cors import CORSMiddleware

app.add_middleware(
    CORSMiddleware,
    allow_origins=["http://localhost:3000"],  # ou "*" pra permitir tudo (somente dev)
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"])

# %%
# Limitação de requisições
limiter = Limiter(key_func=get_remote_address)
app.state.limiter = limiter

# %%
# Redirecionar todos os acessos para HTTPS (só na produção)
if os.getenv("ENV") == "production":
    app.add_middleware(HTTPSRedirectMiddleware)

# %%
# Tratamento de erro de limite de requisições
@app.exception_handler(RateLimitExceeded)
async def rate_limit_handler(request: Request, exc: RateLimitExceeded):
    return JSONResponse(status_code=429, content={"detail": "Muitas tentativas, tente novamente mais tarde."})

# %% [markdown]
# ### Auxiliares de autenticação

# %%
# Abre uma sessão assíncrona com o banco de dados.
async def get_db():
    async with async_session() as session:
        yield session

# %%
# Compara uma senha enviada pelo usuário com o hash da senha armazenado no banco
def verificar_senha(senha, hash):
    return pwd_context.verify(senha, hash)

# %%
# Cria um hash de uma senha de forma segura.
def criar_hash_senha(senha):
    return pwd_context.hash(senha)

# %%
# Gera um token JWT para o usuário, incluindo o conteúdo de data + uma data de expiração (exp).
def criar_token(data: dict, expira_min=15):
    dados = data.copy()
    expira = datetime.utcnow() + timedelta(minutes=expira_min)
    dados.update({"exp": expira})
    return jwt.encode(dados, SECRET_KEY, algorithm=ALGORITHM)

# %%
# Consulta o banco buscando um Usuario pelo e-mail.
async def obter_usuario_email(db: AsyncSession, email: str):
    result = await db.execute(select(Usuario).where(Usuario.email == email))
    return result.scalar_one_or_none()

# %%
# Decodifica o token JWT enviado pelo front-end e busca no banco o usuário correspondente.
# Se o token for inválido, expirado ou não tiver o e-mail, dispara um erro 401 Unauthorized.
async def obter_usuario_token(token: str = Depends(oauth2_scheme), db: AsyncSession = Depends(get_db)):
    try:
        payload = jwt.decode(token, SECRET_KEY, algorithms=[ALGORITHM])
        email = payload.get("sub")
        if email is None:
            raise HTTPException(status_code=401)
        usuario = await obter_usuario_email(db, email)
        if usuario is None:
            raise HTTPException(status_code=401)
        return usuario
    except JWTError:
        raise HTTPException(status_code=401)

# %% [markdown]
# ### Rotas de autenticação

# %%
# Registro de usuário
@app.post("/auth/register")
async def registrar(nome: str, email: str, senha: str, db: AsyncSession = Depends(get_db)):
    resultado = await db.execute(select(Usuario).filter(Usuario.email == email))
    if resultado.scalars().first():
        raise HTTPException(status_code=400, detail="Email já registrado")

    usuario = Usuario(nome=nome, email=email, senha=criar_hash_senha(senha))
    db.add(usuario)
    await db.commit()
    await db.refresh(usuario)
    return {"msg": "Usuário criado", "id": usuario.id}

# %%
# Autenticação de login

MAX_TENTATIVAS = 5
BLOQUEIO_MINUTOS = 10

@app.post("/auth/login")
async def login(form: OAuth2PasswordRequestForm = Depends(), db: AsyncSession = Depends(get_db)):
    # Verificar tentativas de login
    result = await db.execute(select(TentativaLogin).filter(TentativaLogin.email == form.username))
    tentativa = result.scalars().first()

    if tentativa:
        tempo_desde_ultima = datetime.utcnow() - tentativa.ultima_tentativa
        if tentativa.tentativas >= MAX_TENTATIVAS and tempo_desde_ultima < timedelta(minutes=BLOQUEIO_MINUTOS):
            raise HTTPException(status_code=429, detail="Muitas tentativas. Tente novamente mais tarde.")

    # Verificar credenciais
    result = await db.execute(select(Usuario).filter(Usuario.email == form.username))
    usuario = result.scalars().first()

    if not usuario or not verificar_senha(form.password, usuario.senha):
        if not tentativa:
            tentativa = TentativaLogin(email=form.username, tentativas=1)
            db.add(tentativa)
        else:
            tentativa.tentativas += 1
            tentativa.ultima_tentativa = datetime.utcnow()
        await db.commit()
        raise HTTPException(status_code=401, detail="Credenciais inválidas")

    # Login válido
    if tentativa:
        await db.delete(tentativa)
    access_token = criar_token({"sub": usuario.email}, expira_min=15)
    refresh_token = criar_token({"sub": usuario.email}, expira_min=60 * 24 * 7)
    await db.commit()

    return {
        "access_token": access_token,
        "refresh_token": refresh_token,
        "token_type": "bearer"
    }

# %%
# Renovação do token
@app.post("/auth/refresh")
async def renovar_token(refresh_token: str, db: AsyncSession = Depends(get_db)):
    try:
        payload = jwt.decode(refresh_token, SECRET_KEY, algorithms=[ALGORITHM])
        email = payload.get("sub")
        if email is None:
            raise HTTPException(status_code=401)

        result = await db.execute(select(Usuario).filter(Usuario.email == email))
        usuario = result.scalars().first()
        if usuario is None:
            raise HTTPException(status_code=401)

        novo_token = criar_token({"sub": usuario.email}, expira_min=15)
        return {"access_token": novo_token, "token_type": "bearer"}
    except JWTError:
        raise HTTPException(status_code=401, detail="Token inválido ou expirado")

# %% [markdown]
# ### Rotas de manipulação dos dados

# %%
@app.post("/agentes", response_model=AgenteOut)
@limiter.limit("10/minute")
async def criar_agente(
    request: Request,
    agente_in: AgenteCreate,
    usuario: Usuario = Depends(obter_usuario_token),
    db: AsyncSession = Depends(get_async_session),
):
    faixa_etaria_calculada = calcular_idade_em_anos(agente_in.data_nascimento)

    info = await db.execute(
        select(MunicipioInfo).where(MunicipioInfo.municipio == agente_in.municipio)
    )
    info = info.scalar_one_or_none()
    if not info:
        raise HTTPException(status_code=404, detail="Município não encontrado")

    novo_agente = Agente(
        usuario_id=usuario.id,
        nu_cpf=agente_in.nu_cpf,
        nu_cns_cnes=agente_in.nu_cns_cnes,
        co_especialidade=agente_in.co_especialidade,
        co_nivel_escolaridade=agente_in.co_nivel_escolaridade,
        co_capacitacao=agente_in.co_capacitacao,
        co_cbo_cnes=agente_in.co_cbo_cnes,
        ds_vinculo_empregaticio=agente_in.ds_vinculo_empregaticio,
        ds_cargo=agente_in.ds_cargo,
        co_faixa_etaria=faixa_etaria_calculada,
        co_genero=agente_in.co_genero,
        co_unidade_vigilancia_sanitaria=agente_in.co_unidade_vigilancia_sanitaria,
        municipio=agente_in.municipio,
        regiao_saude=info.regiao_saude,
        crs=info.crs,
        macrorregiao=info.macrorregiao,
    )

    db.add(novo_agente)
    await db.commit()
    await db.refresh(novo_agente)
    return novo_agente

# %%
# Listagem com filtros
@app.post("/agentes/filtrar")
async def listar_agentes_filtrados(
    filtros: FiltroAgente,
    pagina: int = Query(1, ge=1),
    tamanho: int = Query(10, ge=1),
    usuario: Usuario = Depends(obter_usuario_token),
    db: AsyncSession = Depends(get_async_session)
):
    query_base = select(Agente).where(Agente.usuario_id == usuario.id)
    condicoes = []

    if filtros.municipio:
        condicoes.append(Agente.co_unidade_vigilancia_sanitaria.ilike(f"%{filtros.municipio}%"))
    if filtros.co_especialidade:
        condicoes.append(Agente.co_especialidade == filtros.co_especialidade)
    if filtros.co_genero:
        condicoes.append(Agente.co_genero == filtros.co_genero)
    if filtros.nu_cpf:
        condicoes.append(Agente.nu_cpf == filtros.nu_cpf)

    if condicoes:
        query_base = query_base.where(*condicoes)

    ordenaveis = {
        "municipio": Agente.co_unidade_vigilancia_sanitaria,
        "criado_em": Agente.criado_em,
        "nome": Agente.nu_cpf,  # Ajuste se tiver campo real de nome
        "cpf": Agente.nu_cpf
    }

    campo_ordenacao = ordenaveis.get(filtros.order_by, Agente.criado_em)
    if filtros.order_dir == "asc":
        query_base = query_base.order_by(campo_ordenacao.asc())
    else:
        query_base = query_base.order_by(campo_ordenacao.desc())

    total = await db.scalar(select(func.count()).select_from(query_base.subquery()))
    resultado = await db.execute(
        query_base.offset((pagina - 1) * tamanho).limit(tamanho)
    )
    agentes = resultado.scalars().all()

    return {
        "total": total,
        "pagina": pagina,
        "tamanho": tamanho,
        "itens": agentes
    }

# %%
# Listagem com filtros via URL
@app.get("/agentes")
async def listar_agentes(
    filtro: Annotated[FiltroAgente, Depends()],
    skip: int = 0,
    limit: int = 10,
    usuario: Usuario = Depends(obter_usuario_token),
    db: AsyncSession = Depends(get_async_session)
):
    query = select(Agente).where(Agente.usuario_id == usuario.id)

    if filtro.nu_cpf:
        query = query.where(Agente.nu_cpf == filtro.nu_cpf)
    if filtro.municipio:
        query = query.where(Agente.municipio == filtro.municipio)
    if filtro.co_genero:
        query = query.where(Agente.co_genero == filtro.co_genero)
    if filtro.co_especialidade:
        query = query.where(Agente.co_especialidade == filtro.co_especialidade)

    total_query = await db.execute(
        select(func.count()).select_from(query.subquery())
    )
    total = total_query.scalar()

    order_col = getattr(Agente, filtro.order_by, Agente.criado_em)
    order_func = order_col.desc() if filtro.order_dir == "desc" else order_col.asc()
    query = query.order_by(order_func).offset(skip).limit(limit)

    result = await db.execute(query)
    agentes = result.scalars().all()

    return {
        "total": total,
        "page": (skip // limit) + 1,
        "per_page": limit,
        "data": agentes
    }

# %% [markdown]
# ### Iniciar servidor

# %%
def start_server():
    config = uvicorn.Config(app, host="127.0.0.1", port=8000, log_level="info")
    server = uvicorn.Server(config)
    server.run()

# Rodar o servidor em uma thread (sem travar o notebook)
thread = threading.Thread(target=start_server, daemon=True)
thread.start()
# Out:
# INFO:     Started server process [13644]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 10048] error while attempting to bind on address ('127.0.0.1', 8000): normalmente é permitida apenas uma utilização de cada endereço de soquete (protocolo/endereço de rede/porta)
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     127.0.0.1:65395 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65396 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65397 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65398 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65399 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65400 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65395 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:65396 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49165 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49166 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49167 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49168 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49169 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49170 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49166 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49165 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49220 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49221 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49222 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49223 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49224 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49225 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49221 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49220 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49330 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49332 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49331 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49333 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49334 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49335 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49330 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49332 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49378 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49377 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49379 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49381 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49380 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49382 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49377 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49378 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49403 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49404 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49405 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49406 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49407 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49668 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49403 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49404 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49695 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49697 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49696 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49702 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49703 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49706 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49697 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49695 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49844 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49845 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49846 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49848 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49847 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49849 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49844 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49845 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49964 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49965 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49966 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49967 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49968 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49969 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49968 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49964 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49981 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49982 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49983 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49984 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49985 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49986 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49983 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49982 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50062 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50063 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50064 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50065 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50067 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50066 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50062 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50063 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50082 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50083 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50084 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50085 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50086 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50087 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50082 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50083 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50101 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50102 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50103 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50104 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50105 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50106 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50101 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50103 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50118 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50120 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50122 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50121 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50123 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50119 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50121 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50118 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50138 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50139 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50140 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50141 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50142 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50143 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50138 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50139 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50161 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50165 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50162 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50163 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50164 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50161 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50166 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50163 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50178 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50179 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50181 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50180 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50182 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50183 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50179 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50178 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50222 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50223 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50224 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50225 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50226 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50227 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50222 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50226 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50239 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50241 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50240 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50242 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50243 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50244 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50239 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50241 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50273 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50277 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50276 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50275 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50278 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50274 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50273 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50277 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50277 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50273 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50274 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50278 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50275 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50276 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50273 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50277 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50301 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50302 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50303 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50304 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50306 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50305 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50301 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50302 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50346 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50348 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50347 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50349 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50350 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50351 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50346 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50348 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50385 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50386 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50387 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50388 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50389 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50390 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50385 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50386 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50404 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50405 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50406 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50407 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50408 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50409 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50404 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50405 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50476 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50477 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50478 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50479 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50480 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50481 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50476 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50477 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50477 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50476 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50481 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50479 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50478 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50480 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50477 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50476 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50973 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50975 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50974 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50976 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50977 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50978 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50973 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50975 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51009 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51010 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51011 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51012 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51013 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51014 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51009 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51010 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51021 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51022 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51023 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51025 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51024 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51026 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51021 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51022 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51033 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51034 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51036 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51035 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51037 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51038 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51033 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51034 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51034 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51035 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51033 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51037 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51036 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51038 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51034 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51035 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51048 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51049 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51050 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51051 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51052 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51053 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51048 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51049 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51063 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51064 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51065 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51066 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51067 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51068 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51063 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51066 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51075 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51076 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51077 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51078 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51079 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51080 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51077 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51076 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51087 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51088 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51089 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51090 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51091 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51092 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51088 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51089 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51099 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51100 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51101 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51102 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51103 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51104 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51099 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51100 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51113 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51115 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51114 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51116 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51117 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51118 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51115 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51113 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51143 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51144 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51145 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51148 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51147 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51146 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51145 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51143 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51209 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51210 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51211 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51214 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51213 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51212 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51209 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51210 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51221 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51222 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51223 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51224 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51225 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51226 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51221 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51222 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51233 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51234 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51235 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51236 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51237 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51238 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51233 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51234 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51245 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51246 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51245 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51247 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51246 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51248 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51249 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51250 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51257 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51258 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51259 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51260 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51261 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51262 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51257 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51260 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51269 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51270 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51271 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51272 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51273 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51274 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51270 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51269 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51283 - "GET /opcoes/especialidades HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51284 - "GET /opcoes/nivel_escolaridade HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51285 - "GET /opcoes/capacitacoes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51286 - "GET /opcoes/cbo_cnes HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51287 - "GET /opcoes/vinculos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51288 - "GET /opcoes/cargos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51284 - "GET /opcoes/generos HTTP/1.1" 200 OK
# INFO:     127.0.0.1:51283 - "GET /opcoes/unidades_vigilancia HTTP/1.1" 200 OK
